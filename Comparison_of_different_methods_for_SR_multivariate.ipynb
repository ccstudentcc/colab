# %% [markdown]
# <a href="https://colab.research.google.com/github/ccstudentcc/colab/blob/main/Comparison_of_different_methods_for_SR_multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/KAN-Symbolic_Regression/
# Out:
# /content/drive/MyDrive/KAN-Symbolic_Regression

# %%
# !pip install pykan sympy
# !pip install "autora" pykan gplearn feyn
# !pip install -U "autora[theorist-bms]"
# Out:
# Requirement already satisfied: pykan in /usr/local/lib/python3.12/dist-packages (0.2.8)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)
# Requirement already satisfied: autora in /usr/local/lib/python3.12/dist-packages (4.2.0)
# Requirement already satisfied: pykan in /usr/local/lib/python3.12/dist-packages (0.2.8)
# Requirement already satisfied: gplearn in /usr/local/lib/python3.12/dist-packages (0.4.2)
# Requirement already satisfied: feyn in /usr/local/lib/python3.12/dist-packages (3.4.1)
# Requirement already satisfied: autora-core in /usr/local/lib/python3.12/dist-packages (from autora) (5.0.3)
# Requirement already satisfied: autora-synthetic in /usr/local/lib/python3.12/dist-packages (from autora) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from gplearn) (1.6.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gplearn) (1.5.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from feyn) (1.26.4)
# Requirement already satisfied: pynacl in /usr/local/lib/python3.12/dist-packages (from feyn) (1.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from feyn) (2.2.2)
# Requirement already satisfied: lark in /usr/local/lib/python3.12/dist-packages (from feyn) (1.3.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.12/dist-packages (from feyn) (1.4.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from feyn) (3.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from feyn) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->feyn) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->gplearn) (3.6.0)
# Requirement already satisfied: typer[all] in /usr/local/lib/python3.12/dist-packages (from autora-core->autora) (0.20.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->feyn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->feyn) (2025.2)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pynacl->feyn) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->feyn) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.4.1->pynacl->feyn) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->feyn) (1.17.0)
# WARNING: typer 0.20.0 does not provide the extra 'all'
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora) (8.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer[all]->autora-core->autora) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer[all]->autora-core->autora) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer[all]->autora-core->autora) (0.1.2)
# Requirement already satisfied: autora[theorist-bms] in /usr/local/lib/python3.12/dist-packages (4.2.0)
# Requirement already satisfied: autora-core in /usr/local/lib/python3.12/dist-packages (from autora[theorist-bms]) (5.0.3)
# Requirement already satisfied: autora-synthetic in /usr/local/lib/python3.12/dist-packages (from autora[theorist-bms]) (2.2.0)
# Requirement already satisfied: autora-theorist-bms in /usr/local/lib/python3.12/dist-packages (from autora[theorist-bms]) (1.0.6)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.12/dist-packages (from autora-core->autora[theorist-bms]) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from autora-core->autora[theorist-bms]) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from autora-core->autora[theorist-bms]) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from autora-core->autora[theorist-bms]) (1.6.1)
# Requirement already satisfied: typer[all] in /usr/local/lib/python3.12/dist-packages (from autora-core->autora[theorist-bms]) (0.20.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from autora-theorist-bms->autora[theorist-bms]) (4.67.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from autora-theorist-bms->autora[theorist-bms]) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->autora-core->autora[theorist-bms]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->autora-core->autora[theorist-bms]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->autora-core->autora[theorist-bms]) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autora-core->autora[theorist-bms]) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autora-core->autora[theorist-bms]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->autora-core->autora[theorist-bms]) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->autora-theorist-bms->autora[theorist-bms]) (1.3.0)
# WARNING: typer 0.20.0 does not provide the extra 'all'
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora[theorist-bms]) (8.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora[theorist-bms]) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora[theorist-bms]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer[all]->autora-core->autora[theorist-bms]) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->autora-core->autora[theorist-bms]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer[all]->autora-core->autora[theorist-bms]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer[all]->autora-core->autora[theorist-bms]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer[all]->autora-core->autora[theorist-bms]) (0.1.2)

# %%
import pickle

import feyn
import numpy as np
import pandas as pd
import torch
from autora.theorist.bms import BMSRegressor
from feyn import Model
from gplearn.functions import make_function
from gplearn.genetic import SymbolicRegressor
from kan import KAN as PyKAN, create_dataset
from kan.utils import add_symbolic
from matplotlib import font_manager
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Comparison of Symbolic Regression using Kolmogorov-Arnold Networks (KANs), Genetic Programming methods and Bayes-based methods
#
# In this notebook, we will compare three **symbolic regression** techniques for learning this **multivariate** mathematical function:
#
# $$
# y = sin(x_1^2) + e^{\frac{x_2}{4}} + 1
# $$
#
# 1. **Kolmogorov-Arnold-Networks (KAN)**: We will train a KAN using the official **PyKAN** library, to perform symbolic regression.
#
# 2. **Genetic Programming**: We will use the **gplearn** library, which implements genetic programming, to find a symbolic representation of the function using evolutionary techniques.
#
# 3. **Bayesian Symbolic Regression (BSR)**: We will use the [autora](https://pypi.org/project/autora/) library to solve the symbolic regression task using the Bayesian approach.
#
# 4. **QLattice**: QLattice is the winner of the Synthetic Track of the [SRBench Competition 2022](https://cavalab.org/srbench/competition-2022/).

# %% [markdown]
# ## Dataset definition and plotting

# %%
sin_exp = lambda x: torch.sin(x[:, 0] ** 2) + torch.exp(x[:, 1] / 4) + 1
noise_std = .05
dataset = create_dataset(sin_exp, n_var=2, ranges=[-4, 4], train_num=30000, test_num=5000,
                         normalize_input=True, normalize_label=True)
# dataset['train_label'] += np.random.normal(0, noise_std, (1000, ))
Xs, Ys = dataset['train_input'], dataset['train_label']

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(10, 10))
ax.scatter(Xs[:, 0], Xs[:, 1], Ys[:, 0], c='blue', marker='.', alpha=0.4, linewidths=.5)
plt.show()

# %% [markdown]
# ## 1. Using a KAN

# %%
kan_model = PyKAN.loadckpt('model/0.9')
kan_model.plot()

# %%
kan_model = PyKAN(width=[2, 2, 1], grid=4, k=3)
pass
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
kan_model.fit(dataset, opt='LBFGS', steps=50, lamb=0.001, lamb_entropy=4)
kan_model.plot()
# Out:
# | train_loss: 2.54e-02 | test_loss: 2.51e-02 | reg: 1.40e+01 | : 100%|█| 50/50 [02:13<00:00,  2.67s/
# saving model version 0.1

# %%
Xs2 = torch.cartesian_prod(torch.linspace(-1.5, 1.5, 500), torch.linspace(-1.5, 1.5, 200))
with torch.no_grad():
    Ys2 = kan_model(Xs2)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Xs2[:, 0], Xs2[:, 1], Ys2[:, 0], c='blue', marker='.', alpha=0.15, linewidths=0.75)
plt.show()

# %% [markdown]
# ## 2. Using a Gplearn

# %%
with open("multivariate_gplearn_model.pkl", "rb") as f:
    genetic_model: SymbolicRegressor = pickle.load(f)

# %%
def _exponent(x):
    with np.errstate(divide='ignore', invalid='ignore'):
        a = np.exp(x)
        a[np.greater(a, 10)] = 10
        a[np.less(a, 1 / 10.)] = 1 / 10.
        return a


exp = make_function(function=_exponent, name='exp', arity=1)
genetic_model = SymbolicRegressor(
    population_size=20000,
    generations=5,
    init_depth=(4, 10),
    metric='mse',
    function_set=('add', 'mul', 'sin', exp),
    n_jobs=-1,
    verbose=1,
)

# %%
genetic_model.fit(Xs, Ys)
with open("multivariate_gplearn_model.pkl", "wb") as f:
    pickle.dump(genetic_model, f)
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    46.41      2.21684e+13       19         0.508121              N/A      6.93m
#    1    18.28          3.59768       17         0.499561              N/A      2.65m
#    2     4.23          14.7033       17         0.499561              N/A     48.47s
#    3     4.22          1.88302       18         0.497849              N/A     25.88s
#    4     3.97         0.990406       18         0.497849              N/A      0.00s

# %% [markdown]
# ## 3. Using BMS Regressor

# %%
with open("multivariate_bms_model.pkl", "rb") as f:
    bms_model: BMSRegressor = pickle.load(f)

# %%
bms_model = BMSRegressor(
    epochs=200,
    ts=[1.0] + [1.03 ** k for k in range(1, 40)],
)

# %%
bms_model.fit(Xs, Ys)
with open("multivariate_bms_model.pkl", "wb") as f:
    pickle.dump(bms_model, f)
# Out:
#   6%|▌         | 11/200 [00:03<01:03,  2.98it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/mcmc.py in update_representative(self, verbose)
#     796         try:  # We've seen this canonical before!
# --> 797             rep, rep_energy, rep_par_values = self.representative[canonical]
#     798         except TypeError:
#
# KeyError: 'X1/relu(X0)'
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# /tmp/ipython-input-2799720071.py in <cell line: 0>()
# ----> 1 bms_model.fit(Xs, Ys)
#       2 with open("multivariate_bms_model.pkl", "wb") as f:
#       3     pickle.dump(bms_model, f)
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/regressor.py in fit(self, X, y, num_param, root, custom_ops, seed)
#     133             seed=seed,
#     134         )
# --> 135         self.model_, self.loss_, self.cache_ = utils.run(self.pms, self.epochs)
#     136         self.models_ = list(self.pms.trees.values())
#     137
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/utils.py in run(pms, num_steps, thinning)
#      33     desc_len, model, model_len = [], pms.t1, np.inf
#      34     for n in tqdm(range(num_steps)):
# ---> 35         pms.mcmc_step()
#      36         pms.tree_swap()
#      37         if num_steps % thinning == 0:  # sample less often if we thin more
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/parallel.py in mcmc_step(self, verbose, p_rr, p_long)
#     100         for T, tree in list(self.trees.items()):
#     101             # MCMC step
# --> 102             tree.mcmc_step(verbose=verbose, p_rr=p_rr, p_long=p_long)
#     103         self.t1 = self.trees["1.0"]
#     104
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/mcmc.py in mcmc_step(self, verbose, p_rr, p_long)
#    1256             sf = len(self.et_space[ofin])
#    1257             # Probability of acceptance
# -> 1258             dE, dEB, dEP, par_valuesNew, nif, nfi = self.dE_et(
#    1259                 target, new, verbose=verbose
#    1260             )
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/mcmc.py in dE_et(self, target, new, verbose)
#     851         )
#     852         # check/update canonical representative
# --> 853         rep_res = self.update_representative(verbose=verbose)
#     854         if rep_res == -1:
#     855             # this formula is forbidden
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/mcmc.py in update_representative(self, verbose)
#     800         except KeyError:  # Never seen this canonical formula before:
#     801             # save it and return 1
# --> 802             self.get_bic(reset=True, fit=True, verbose=verbose)
#     803             new_energy = self.get_energy(bic=False, verbose=verbose)
#     804             self.representative[canonical] = (
#
# /usr/local/lib/python3.12/dist-packages/autora/theorist/bms/mcmc.py in get_bic(self, reset, fit, verbose)
#     735             else:
#     736                 n = len(self.y[ds])
# --> 737                 BIC += (k - n) * np.log(n) + n * (np.log(2.0 * np.pi) + log(sse[ds]) + 1)
#     738         if reset:
#     739             self.bic = BIC
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/function.py in __new__(cls, *args, **options)
#     464
#     465         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466         result = super().__new__(cls, *args, **options)
#     467         if evaluate and isinstance(result, cls) and result.args:
#     468             _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/function.py in __new__(cls, *args, **options)
#     295         from sympy.sets.sets import FiniteSet
#     296
# --> 297         args = list(map(sympify, args))
#     298         evaluate = options.pop('evaluate', global_parameters.evaluate)
#     299         # WildFunction (and anything else like it) may have nargs defined
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     409         import numpy as np
#     410         if np.isscalar(a):
# --> 411             return _convert_numpy_types(a, locals=locals,
#     412                 convert_xor=convert_xor, strict=strict, rational=rational,
#     413                 evaluate=evaluate)
#
# /usr/local/lib/python3.12/dist-packages/sympy/core/sympify.py in _convert_numpy_types(a, **sympify_args)
#      91         # E.g. double precision means prec=53 but nmant=52
#      92         # Leading bit of mantissa is always 1, so is not stored
# ---> 93         p, q = a.as_integer_ratio()
#      94         a = mlib.from_rational(p, q, prec)
#      95         return Float(a, precision=prec)
#
# OverflowError: cannot convert Infinity to integer ratio

# %% [markdown]
# ## 4. Using QLattice

# %%
with open("multivariate_qlattice_model.pkl", "rb") as f:
    qlattice_models: list[Model] = pickle.load(f)

# %%
ql = feyn.QLattice()
data = pd.DataFrame({
    'x1': Xs[:, 0].flatten(),
    'x2': Xs[:, 1].flatten(),
    'y': Ys.flatten()
})
qlattice_models = ql.auto_run(data, output_name='y', n_epochs=20)

# %%
qlattice_models[0].fit(data)
with open("multivariate_qlattice_model.pkl", "wb") as f:
    pickle.dump(qlattice_models, f)

# %%
sympy_model = qlattice_models[0].sympify(signif=2)
sympy_model.as_expr()
# Out:
# 4.6 - 6.8*exp(-0.12*(-0.17*x2 - 1)**2*(0.41*x2 + 1)**2 - 4.1*(exp(-6.3*(1 - 0.83*x1)**2*(-0.81*x1 - 1)**2 - 0.46*(1 - 0.017*x2)**2) - 0.28)**2)

# %% [markdown]
# ## Comparison of model results

# %%
Xs2 = torch.cartesian_prod(torch.linspace(-1.5, 1.5, 500), torch.linspace(-1.5, 1.5, 150))
with torch.no_grad():
    kan_pred = kan_model(Xs)[:, 0], kan_model(Xs2)[:, 0]
    genetic_pred = genetic_model.predict(Xs), genetic_model.predict(Xs2)
    bms_pred = bms_model.predict(Xs)[:, 0], bms_model.predict(Xs2)[:, 0]
    qlattice_pred = qlattice_models[0].predict(pd.DataFrame({
        'x1': Xs[:, 0].flatten(),
        'x2': Xs[:, 1].flatten(),
    })), qlattice_models[0].predict(pd.DataFrame({
        'x1': Xs2[:, 0].flatten(),
        'x2': Xs2[:, 1].flatten(),
    }))

fig = plt.figure(figsize=(20, 7))
models = [('KAN', kan_pred, fig.add_subplot(141, projection='3d'), 'darkred'),
          ('Gplearn', genetic_pred, fig.add_subplot(142, projection='3d'), 'blue'),
          ('BMS Regressor', bms_pred, fig.add_subplot(143, projection='3d'), 'green'),
          ('QLattice', qlattice_pred, fig.add_subplot(144, projection='3d'), 'purple')
          ]
handles = []
for pred in models:
    mse, r2 = mean_squared_error(Ys, pred[1][0]), r2_score(Ys, pred[1][0])
    handles.append(pred[2].scatter(Xs2[:, 0], Xs2[:, 1], pred[1][1],
                                   label=f'{pred[0]}{" " * (max(map(lambda x: len(x[0]), models)) - len(pred[0]))}  |  MSE={mse:.3f}, R2={r2:.3f}',
                                   alpha=0.1, c=pred[3], marker='.', linewidths=0.01))
fig.legend(handles, map(lambda x: x.get_label(), handles),
           prop=font_manager.FontProperties(family='monospace', size=12))
